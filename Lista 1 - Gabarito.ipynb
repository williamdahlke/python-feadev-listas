# %% [markdown]
# # 🚀 Vamos para a primeira lista de exercícios?
#
# Olá, devs! 🐍
#
# A primeira lista de exercícios do curso está no ar! É a sua chance de praticar **variáveis, operadores, tipos de dados e inputs** e fixar o conteúdo inicial. Nada complicado, mas essencial para o que vem pela frente! 💻
#
# ## O que você vai fazer:
# - Manipular **variáveis**
# - Utilizar **operadores** em expressões
# - Trabalhar com **tipos de dados** em Python
# - Coletar dados com **inputs** do usuário
#
# **Dúvidas? Só mandar no <a href="https://forms.gle/Xp77MAWqRv7xjgA56">formulário de dúvidas</a> que está rodando no canal do WhatsApp! Bora codar! 🚀**
# <br>
#
# **Enviar Lista por <a href="https://forms.gle/7wrj3ZLBAVBMpaZp6">aqui</a>**
#
# Abraços,
# **Equipe FEA.dev**

# %% [markdown]
# ## Exercício 1: Planejamento de Viagem (Conversão de Moedas)

# %% [markdown]
# Você está planejando uma viagem internacional e precisa converter seu dinheiro para outra moeda.
#
# 1. **Crie um programa que converta reais (R\$) para dólares (USD)**. O programa deve pedir ao usuário a quantidade em reais e usar uma taxa de câmbio fornecida para calcular o valor correspondente em dólares.
#    - **Exemplo**: Se a taxa de câmbio for 1 USD = 5,30 BRL e você tiver R$ 1.000, qual será o valor em dólares?
#
# 2. **Modifique o programa** para que o usuário converta reais para euros também (use 1 EUR = 5,80 BRL).

# %%
# Pergunta ao usuário qual é a taxa de câmbio entre real e dolar.
taxa_de_cambio_dolar = input("Qual é a taxa de câmbio que será utilizada entre real e dolar? ")

# Pergunta ao usuário qual é a quantidade de reais que serão convertidos para dólares.
quantidade_em_reais = input("Qual é a quantidade de reais que será convertida em dólares? ")

# Converte o valor em reais para um valor em dolar.
# Observe que, antes de realizar os cálculos, os valores "quantidade_em_reais" e "taxa_de_cambio" foram convertidos para float.
valor_em_dolar = float(quantidade_em_reais) / float(taxa_de_cambio_dolar)

# Pula uma linha para separar a aquisição dos dados da exibição dos resultados.
print("\n")

# Imprime o valor convertido em dolar.
print(f"O valor em dólares é: {valor_em_dolar:.2f} $")

# ----------------------------------------------------------------------------------------------------------------------------

# Seta o valor da taxa de câmbio entre real e euro.
taxa_de_cambio_euro = 5.8

# Converte o valor em reais para um valor em euro.
valor_em_euro = float(quantidade_em_reais) / float(taxa_de_cambio_euro)

# Imprime o valor convertido em euro. Observe que o número de casas decimais da saída é formatado usando ":.2f".
print(f"O valor em euros é: {valor_em_euro:.2f} €")
# Out:
# Qual é a taxa de câmbio que será utilizada entre real e dolar? 5.61
# Qual é a quantidade de reais que será convertida em dólares? 1000
#
#
# O valor em dólares é: 178.25 $
# O valor em euros é: 172.41 €

# %% [markdown]
# ## Exercício 2: Cálculo do Consumo de Combustível

# %% [markdown]
# Você está indo em uma viagem de carro e deseja saber quanto combustível gastará.
#
# 1. **Escreva um programa que calcule o consumo de combustível baseado na distância a ser percorrida e no consumo médio do carro (km por litro)**. O programa deve perguntar ao usuário a distância em quilômetros e o consumo médio do carro.
#    - **Exemplo**: Se a distância é de 300 km e o carro faz 12 km/L, quantos litros de combustível serão necessários?
#
# 2. **Adicione um cálculo de custo**, onde o programa pergunta também o preço do litro de combustível e exibe o custo total da viagem.

# %%
# Obs: Veja que os 3 inputs abaixo são diretamente convertidos para float antes de serem salvos em uma variável.

# Pergunta ao usuário qual será a distância a ser percorrida com o carro.
distancia_a_ser_percorrida = float(input("Qual é a distância (em quilômetros) a ser percorrida ? "))

# Pergunta ao usuário qual é o consumo médio do carro.
consumo_medio_do_carro = float(input("Qual é o consumo médio do carro (em quilômetros por litro) ? "))

# Pergunta ao usuário qual é o preço do litro de combustível.
custo_por_litro_de_combustivel = float(input("Qual é o custo do litro de combustível (em R$) ? "))

# Calcula quantos litros de combustível serão gastos na viagem.
litros_de_combustivel_necessarios = distancia_a_ser_percorrida / consumo_medio_do_carro

# Calcula o custo total da viagem.
custo_total_da_viagem = litros_de_combustivel_necessarios*custo_por_litro_de_combustivel

# Pula uma linha para separar a aquisição dos dados da exibição dos resultados.
print("\n")

# Exibe a quantidade de litros de combustível que serão necessários na viagem.
print(f"Serão necessários {litros_de_combustivel_necessarios:.2f} litros de combustível para completar a viagem")

# Exibe o custo total da viagem.
print(f"O custo total da viagem é: {custo_total_da_viagem:.2f} R$")
# Out:
# Qual é a distância (em quilômetros) a ser percorrida ? 200
# Qual é o consumo médio do carro (em quilômetros por litro) ? 10
# Qual é o custo do litro de combustível (em R$) ? 6
#
#
# Serão necessários 20.00 litros de combustível para completar a viagem
# O custo total da viagem é: 120.00 R$

# %% [markdown]
# ## Exercício 3: Gerador de Senhas Personalizadas (Manipulação de Strings)

# %% [markdown]
# Você está criando um sistema que gera senhas personalizadas para os usuários com base em suas informações pessoais. As senhas precisam ser únicas e seguras, mas também fáceis de lembrar.
#
# 1. **Crie um programa que peça ao usuário seu nome e uma data**. O programa deve gerar uma senha usando a seguinte lógica:
#    - As 3 primeiras letras do nome.
#    - Os dois primeiros dígitos do ano.
#    - O número de caracteres do nome completo (incluindo espaços).
#
#    **Exemplo**: Para um usuário chamado "Ana Beatriz Costa" e "15/08/1990", a senha seria: `Ana19 18`.
#
# 2. **Modifique o programa para transformar as letras da senha gerada em letras maiúsculas e adicionar um caractere especial "!" no final da senha**.
#
#    **Exemplo modificado**: A senha final seria: `ANA19 18!`.

# %%
# Pede ao usuário que insira o seu nome.
nome = input("Qual é o seu nome? ")

# Pede ao usuário que insira uma data no formato "DD/MM/AAAA".
data = input("Insira uma data no formato 'DD/MM/AAAA': ")

# Precisamos das 3 primeiras letras do nome inserido pelo usuário, podemos fazer isso obtendo uma letra por vez, veja:
iniciais_nome = nome[0] + nome[1] + nome[2]  # Obtemos e concatenamos as 3 primeiras letras do nome do usuário.
# Obs: Essa operação poderia ser simplificada para iniciais_nome = nome[:3]       (mais detalhes nas próximas aulas =])

# Precisamos dos dois primeiros dígitos do ano, como o ano está no formato 'DD/MM/AAAA' basta que peguemos os dígitos da posição 6 e 7.
# Obs: Em computação, começamos a contar do 0 e não do 1. Ou seja, temos a seguinte relação entre posição e dígito para a data:
#       D - Dígito 0
#       D - Dígito 1
#       / - Dígito 2
#       M - Dígito 3
#       M - Dígito 4
#       / - Dígito 5
#       A - Dígito 6
#       A - Dígito 7
#       A - Dígito 8
#       A - Dígito 9
digitos_ano = data[6] + data[7] # Obtemos e concatenamos os 2 primeiros dígitos do ano.

# Cria a senha no formato especificado (observe que um espaço deve separar a junção das variáveis "iniciais_nome" e "digitos_ano", do número
# de caracteres da variável "nome").
senha = iniciais_nome + digitos_ano + " " + str(len(nome))

# Pula uma linha para separar a aquisição dos dados da exibição dos resultados.
print("\n")

# Exibe a senha sem modificações.
print("Senha sem modificações: " + senha)

# Transforma as letras da senha gerada em letras maiúsculas e adiciona um caractere especial "!" no final da senha.
senha_modificada = senha.upper() + "!"

# Exibe a senha modificada.
print("Senha modificada: " + senha_modificada)
# Out:
# Qual é o seu nome? Ana Beatriz Lima
# Insira uma data no formato 'DD/MM/AAAA': 15/08/1990
#
#
# Senha sem modificações: Ana19 16
# Senha modificada: ANA19 16!

# %% [markdown]
# ## Exercício 4: Cálculo de Juros Simples (Aplicação Financeira)

# %% [markdown]
# Você está pensando em investir uma quantia em um banco e quer saber quanto receberá ao final de um período.
#
# 1. **Escreva um programa que calcule o valor final de uma aplicação de juros simples**, com base no capital inicial, taxa de juros e tempo de investimento. A fórmula é $M = C 	\cdot (1 + i)^{t}$, onde:
#    - \( M \) é o montante final,
#    - \( C \) é o capital inicial,
#    - \( i \) é a taxa de juros anual,
#    - \( t \) é o tempo (em anos).
#    - **Exemplo**: Um investimento de R$ 1.000 a uma taxa de 5% ao ano por 3 anos.
#
# 2. **Permita que o usuário escolha o período de tempo (em meses ou anos)** e faça a conversão correta no cálculo.

# %%
# Pede ao usuário que insira o valor do capital inicial.
capital_inicial = float(input("Qual é o valor do capital inicial? "))

# Pergunta ao usuário se ele quer que a taxa de juros seja mensal ou anual.
periodo_de_tempo = input("Digite 'A' para taxa anual ou 'M' para taxa mensal: ")

# Pede ao usuário que insira o valor da taxa de juros no formato decimal (isto é 5% seria 0.05).
taxa_de_juros = float(input("Qual é o valor da taxa de juros? (insira tal valor no formato decimal, isto é, 5% seria 0.05): "))

# Pede ao usuário que insira o tempo de investimento.
tempo_de_investimento = float(input("Qual é o tempo de investimento? "))

# Usa uma condicional para ajustar o valor da taxa de juros.
if(periodo_de_tempo == "A"):
  taxa_de_juros = taxa_de_juros
else:
  taxa_de_juros = (1 + taxa_de_juros)**(1/12)-1 # Fórmula usada: taxa_mensal = (1 + taxa_anual)^(1/12) - 1.

# Calcula o montante final do investimento.
montante_final = capital_inicial * (1 + taxa_de_juros)**(tempo_de_investimento)

# Pula uma linha para separar a aquisição dos dados da exibição do resultado.
print("\n")

# Exibe o valor do montante final.
print(f"O valor do montante final será: {montante_final:.2f}R$")
# Out:
# O valor do montante final será: 1012.27R$

# %% [markdown]
# # Desafio: Verificação de ID Válido

# %% [markdown]
# Você está trabalhando com um sistema de verificação de identidade, e precisa validar se um número de identificação segue uma regra específica.
#
# 1. **Crie um programa que valide se um número de CPF é válido**, baseado no formato "XXX.XXX.XXX-XX". O programa deve verificar se a entrada tem o número correto de dígitos e o formato correto (não é necessário validar os dígitos verificadores).
#    - **Exemplo**: O programa deve aceitar "123.456.789-00" e rejeitar "12345678900".
#
# 2. **Adicione uma funcionalidade** onde o programa também valida um CNPJ no formato "XX.XXX.XXX/0001-XX".

# %%
# Vamos começar validando um CPF
# Sabemos que o CPF é válido se estiver no formato XXX.XXX.XXX-XX. Portanto, devemos realizar as seguintes verificações:
#       1) O CPF recebido como entrada possui 14 digitos ?
#       2) Os dígitos das posições 3 e 7 são "." ?
#       3) O dígito da posição 11 é um "-" ?

# Pedimos ao usuário para que digite o CPF que ele deseja verificar a validade
cpf = input("Digite o CPF que você deseja verificar a validade: ")

# Criamos uma variável booleana para guardar se o CPF inserido pelo usuário tem o número correto de dígitos ou não (isto é, 14 dígitos).
condicao_1 = len(cpf) == 14

# Criamos uma variável booleana para guardar se os dígitos das posições 3 e 7 são "."
condicao_2 = cpf[3] == "." and cpf[7] == "."

# Criamos uma variável booleana para guardar se o dígito da posição 11 é um "-"
condicao_3 = cpf[11] == "-"

# Pula uma linha para separar a aquisição dos dados da exibição do resultado.
print("\n")

# Criamos uma condicional para ajudar a mostrar se o CPF inserido é válido ou não.
if(condicao_1 and condicao_2 and condicao_3):
  print("CPF válido")
else:
  print("CPF inválido")
# Out:
# Digite o CPF que você deseja verificar a validade: 109.321.132-42
#
#
# CPF válido

# %%
# Vamos validar agora um CNPF
# Sabemos que o CNPF é válido se estiver no formato XX.XXX.XXX/0001-XX. Portanto, devemos realizar as seguintes verificações:
#       1) O CNPJ recebido como entrada possui 18 digitos ?
#       2) Os dígitos das posições 2 e 6 são "." ?
#       3) O dígito da posição 10 é um caractere "/" ?
#       4) A sequência dos caracteres nas posições 11, 12, 13, 14 é igual à 0001 ?
#       5) O dígito da posição 15 é um caractere "-" ?

# Pedimos ao usuário para que digite o CNPJ que ele deseja verificar a validade
cnpj = input("Digite o CNPJ que você deseja verificar a validade: ")

# Criamos uma variável booleana para guardar se o CNPJ inserido pelo usuário tem o número correto de dígitos ou não (isto é, 18 dígitos).
condicao_1 = len(cnpj) == 18

# Criamos uma variável booleana para guardar se os dígitos das posições 3 e 7 são "."
condicao_2 = cnpj[2] == "." and cnpj[6] == "."

# Criamos uma variável booleana para guardar se o dígito da posição 11 é um "-"
condicao_3 = cnpj[10] == "/"

# Criamos uma variável booleana para guardar se a sequência dos caracteres nas posições 12, 13, 14 e 15 é igual à 0001
condicao_4 = cnpj[11] + cnpj[12] + cnpj[13] + cnpj[14] == "0001"

# Criamos uma variável booleana para guardar se o dígito da posição 16 é um "-"
condicao_5 = cnpj[15] == "-"

# Pula uma linha para separar a aquisição dos dados da exibição do resultado.
print("\n")

# Criamos uma condicional para ajudar a mostrar se o CNPJ inserido é válido ou não.
if(condicao_1 and condicao_2 and condicao_3 and condicao_4 and condicao_5):
  print("CNPJ válido")
else:
  print("CNPJ inválido")
# Out:
# Digite o CNPJ que você deseja verificar a validade: XX.XXX.XXX/0001-XX
#
#
# CNPJ válido
